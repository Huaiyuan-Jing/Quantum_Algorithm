# %%
import qiskit
from qiskit import QuantumCircuit

surface_code = QuantumCircuit(5, 1)
surface_code.h(4)
surface_code.cx(4, 0)
surface_code.cx(4, 1)
surface_code.cx(4, 2)
surface_code.cx(4, 3)
surface_code.h(4)
surface_code.measure(4, 0)

display(surface_code.draw('mpl'))
